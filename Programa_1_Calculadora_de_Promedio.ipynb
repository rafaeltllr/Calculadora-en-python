# %% [markdown]
# Programa 1: Calculadora de Promedio

# %%
nota_1 = 80
nota_2 = 90
nota_3 = 98
nota_4 = 83

promedio = (nota_1 + nota_2 + nota_3 + nota_4) / 4

print("Promedio:", promedio)
# Out:
# Promedio: 87.75
